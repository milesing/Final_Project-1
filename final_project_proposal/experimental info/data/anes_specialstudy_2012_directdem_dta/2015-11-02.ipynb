# %%
import pandas as pd
from IPython.core.display import HTML
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'anes_specialstudy_2012_directdem.dta'
voted = pd.read_stata(filename, index = [3])
"""this assignment is incomplete because i have no idea how to reindex an int64Index...."""
# Out:
# 'this assignment is incomplete because i have no idea how to reindex an int64Index....'

# %%
type(voted)
# Out:
# pandas.core.frame.DataFrame

# %%
voted
# Out:
#                                              dd_version  dd_caseid caseid  \
# 0     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20001   3001
# 1     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20002   3004
# 2     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20003   3005
# 3     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20004   3009
# 4     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20005   3016
# 5     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20006   3017
# 6     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20007   3018
# 7     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20008   3023
# 8     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20009   3026
# 9     FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20010   3027
# 10    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20011   3028
# 11    FINAL RELEASE, ANES 2012 Direct Democracy Stud...      20012   3032
# ...

# %%
type(voted.index)
"""what is Int64Index!?!"""
# Out:
# 'what is Int64Index!?!'

# %%
voted.dtypes
# Out:
# dd_version                   object
# dd_caseid                   float32
# caseid                     category
# weight_pre                  float64
# weight_post                 float64
# main_anes                  category
# sample                     category
# dd_pid_x                   category
# dd_rvote2012_x             category
# dd_presvote2012_x          category
# tm_start_ddpre               object
# tm_finish_ddpre              object
# duration_ddpre             category
# pre_xlike2                 category
# pre_revist_split           category
# pre_xnoadd                 category
# dem_hsename                  object
# dem_hseparty                 object
# rep_hsename                  object
# rep_hseparty                 object
# ind_hsename                  object
# ind_hseparty                 object
# dem_pcname                   object
# rep_pcname                   object
# pre_regist                 category
# pre_regist_prompt          category
# ...

# %%
plt.plot(voted.weight_pre).hist(color= 'm', marker = 'o', linestyle ='')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-887fdd9fd1ac> in <module>()
#       1
# ----> 2 plt.plot(voted.weight_pre).hist(color= 'm', marker = 'o', linestyle ='')
#       3
#       4
#       5 plt.show()
#
# AttributeError: 'list' object has no attribute 'hist'

# %%
plt.ylabel('Temperature')
plt.xlabel('Year')
plt.title('Temerature Variance')
#define subplot 2,,,1 row 3columns 2nd subplot
plt.subplot(1, 3, 2)
plt.plot(site_B2.year, site_B2.rainfall)
plt.ylabel('Rainfall')
plt.xlabel('Year')
plt.title('Rainfall Variance')
#define subplot 3,,,1 row 3columns 3rd subplot
plt.subplot(1, 3, 3)
plt.plot(site_B2.year, site_B2.mosquitos, color = 'r')
plt.ylabel("Mosquito Count")
plt.xlabel('Year')
plt.title('MosQito Pop Variance')
#tight plots space that shit
plt.tight_layout(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-4c6ae64a26a0> in <module>()
#       4 #define subplot 2,,,1 row 3columns 2nd subplot
#       5 plt.subplot(1, 3, 2)
# ----> 6 plt.plot(site_B2.year, site_B2.rainfall)
#       7 plt.ylabel('Rainfall')
#       8 plt.xlabel('Year')
#
# NameError: name 'site_B2' is not defined
